# %%
from spork_framework_2020_left import multi_case_algorithm_2020
from spork_framework_2020_loc_left import multi_case_algorithm_2020_loc

import numpy as np
import pandas as pd
from datetime import datetime, timedelta
# Out:
# C:\Users\matts\AppData\Local\Continuum\anaconda3\envs\spork2020\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#List of parameters that feed into SPORK
storm_relative_dirs = np.asarray([355])
zdrlevs = np.asarray([3.25])
kdplevs = np.asarray([1.5])
REFlevs = np.asarray([45])
REFlev1s = np.asarray([50])
big_storms = np.asarray([300])
zero_z_triggers = np.asarray([25])
storm_to_tracks = np.asarray([-999])
years = np.asarray([2019])
months = np.asarray([6])
days = np.asarray([7])
hours = np.asarray([22])
start_mins = np.asarray([50])
durations = np.asarray([0.2])
h_calstm = np.asarray([3500])
calibrations = np.asarray([0.0])
stations = ['KBRO']

#New Parameters--these are set as defaults in the multi_case_algorithm_2020 call but can be changed
storm_motion_dir = np.asarray([240])
track_dis = np.asarray([10])
GR_mins = np.asarray([6.0])
# Out:
# C:\Users\matts\AppData\Local\Continuum\anaconda3\envs\spork2020\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#TEST LOOP-to test modifications of the algorithm
print(datetime.utcnow())
#for i in range(len(durations)):
#Re-run: 0, 2, 4, 6, 8, 9, 10, 11 (for z thresholds), 12
#for i in [5]:
for i in [0]:
    #print(multi_case_algorithm_ML1(150,3.25,1.5,45,50,300,25,2,2013,8,10,18,0,1.0,-0.03755074,'KAKQ',4623))
    
    #tracks_dataframe, zdroutlines, col_areas, col_lon, col_storm_lon = multi_case_algorithm_ML1_devRF(storm_relative_dirs[i],3.25,1.5,REFlevs[i],REFlev1s[i],big_storms[i],70,-1,years[i],months[i],days[i],hours[i],start_mins[i],durations[i],calibrations[i],stations[i],h_calstm[i], 240, localfolder[i], track_dis=10, GR_mins=6.0)
    tracks_dataframe, zdroutlines, col_areas, col_lon, col_storm_lon = multi_case_algorithm_2020(storm_relative_dirs[i],3.25,1.5,REFlevs[i],REFlev1s[i],big_storms[i],70,-1,years[i],months[i],days[i],hours[i],start_mins[i],durations[i],calibrations[i],stations[i],h_calstm[i], 240, track_dis=10, GR_mins=6.0)

    #tracks_dataframe, zdroutlines, col_areas, col_lon, col_storm_lon = multi_case_algorithm_ML1_devLOCAL(storm_relative_dirs[i],3.25,1.5,REFlevs[i],REFlev1s[i],big_storms[i],70,storm_to_tracks[i],years[i],months[i],days[i],hours[i],start_mins[i],durations[i],calibrations[i],stations[i],h_calstm[i], localfolder[i], track_dis=10)

    tracks_dataframe.to_pickle('SPORK_RFN_2020'+str(years[i])+str(months[i])+str(days[i])+str(stations[i])+'.pkl')
print(datetime.utcnow())
# Out:
# C:\Users\matts\AppData\Local\Continuum\anaconda3\envs\spork2020\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2021-09-25 20:38:37.984281
# Downloaded KBRO20190607_225527_V06
# Downloaded KBRO20190607_230148_V06
# 2 out of 2 files downloaded...0 errors
# C:\Users\matts\AppData\Local\Continuum\anaconda3\envs\spork2020\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.22.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...
